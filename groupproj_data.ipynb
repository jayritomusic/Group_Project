# %%
import numpy as np

data = np.genfromtxt("ASTR19_F24_group_project_data.txt",
                     dtype=[('myint','i8'),('mystring','S5'),('myfloat','f8')])

day = []
time = []
height = []

print(data)
print(data.shape)

for i in range(82):
    day.append(data[i][0])
    time.append(data[i][1].decode("uft-8"))
    height.append(data[i][2])
    
    
print(day)
print('')
print(time)
print('')
print(day)
print(height)
# Out:
# [( 1, b'8:07',  6.57) ( 1, b'15:37', -0.39) ( 2, b'8:55',  5.38)
#  ( 2, b'16:25', -1.74) ( 3, b'9:45',  5.26) ( 3, b'17:14', -1.36)
#  ( 4, b'10:35',  4.13) ( 4, b'18:00', -1.15) ( 5, b'11:28',  3.48)
#  ( 5, b'18:46', -1.61) ( 6, b'12:22',  2.62) ( 6, b'19:31',  0.05)
#  ( 7, b'13:24',  1.83) ( 7, b'20:16',  1.01) ( 8, b'3:22',  3.57)
#  ( 8, b'21:01',  0.73) ( 9, b'4:07',  4.54) ( 9, b'21:46',  2.17)
#  (10, b'4:50',  3.76) (10, b'11:58',  2.88) (11, b'5:31',  3.9 )
#  (11, b'12:56',  1.92) (12, b'6:08',  4.73) (12, b'13:45',  1.74)
#  (13, b'6:47',  5.66) (13, b'14:25',  0.79) (14, b'7:22',  5.33)
#  (14, b'15:00', -0.04) (15, b'7:59',  5.23) (15, b'15:34', -1.12)
#  (16, b'8:34',  6.67) (16, b'16:08', -0.61) (17, b'9:10',  4.74)
#  (17, b'16:41', -0.93) (18, b'9:45',  4.69) (18, b'17:12', -1.29)
#  (19, b'10:21',  4.2 ) (19, b'17:45',  0.22) (20, b'10:57',  3.68)
#  (20, b'18:15',  0.26) (21, b'11:38',  2.47) (21, b'18:48',  0.36)
#  (22, b'12:25',  2.59) (22, b'19:20',  0.99) (23, b'2:22',  4.1 )
#  (23, b'19:52',  1.87) (24, b'2:58',  3.17) (24, b'20:30',  1.6 )
#  (25, b'3:37',  3.71) (25, b'10:44',  3.1 ) (26, b'4:23',  4.04)
#  (26, b'11:55',  2.49) (27, b'5:15',  4.07) (27, b'12:57',  2.18)
#  (28, b'6:09',  5.93) (28, b'13:50',  0.7 ) (29, b'7:05',  6.89)
#  (29, b'14:39',  0.21) (30, b'7:58',  6.72) (30, b'15:27',  0.22)
#  (31, b'8:50',  6.77) (31, b'16:10', -1.68) (32, b'9:40',  5.77)
#  (32, b'16:52', -1.32) (33, b'10:30',  4.35) (33, b'17:34', -0.73)
#  (34, b'11:19',  4.23) (34, b'18:12', -0.38) (35, b'12:10',  2.24)
#  (35, b'18:49', -0.61) (36, b'1:32',  3.45) (36, b'19:24', -0.46)
#  (37, b'2:13',  4.13) (37, b'20:00',  1.21) (38, b'2:54',  3.34)
#  (38, b'9:54',  2.58) (39, b'3:39',  3.32) (39, b'11:15',  3.26)
#  (40, b'4:29',  5.21) (40, b'12:22',  2.39) (41, b'5:21',  4.83)
#  (41, b'13:14',  2.41)]
# (82,)
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 15
#      13 for i in range(82):
#      14     day.append(data[i][0])
# ---> 15     time.append(data[i][1].decode("uft-8"))
#      16     height.append(data[i][2])
#      19 print(day)
#
# LookupError: unknown encoding: uft-8
